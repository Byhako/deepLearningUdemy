# %% [markdown]
# Vamos a comparar una regresión hecha con sklear con una hecha con keras.

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
boston_housing = keras.datasets.boston_housing
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()
features = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

df_train = pd.DataFrame(np.column_stack([X_train, y_train]), columns=features)
print(df_train.shape)
df_train.head(10)
# Out:
# (404, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 5  0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# 6  9.18702   0.0  18.10   0.0  0.700  5.536  100.0  1.5804  24.0  666.0
# 7  4.09740   0.0  19.58   0.0  0.871  5.468  100.0  1.4118   5.0  403.0
# 8  2.15505   0.0  19.58   0.0  0.871  5.628  100.0  1.5166   5.0  403.0
# 9  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394   4.0  437.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     21.0  396.90  18.72  15.2
# 1     14.7  395.38   3.11  42.3
# 2     20.2  375.52   3.26  50.0
# 3     20.2  396.90   8.01  21.1
# 4     20.2  391.43  14.65  17.7
# 5     19.6  391.13  11.74  18.5
# 6     20.2  396.90  23.60  11.3
# 7     14.7  396.90  26.42  15.6
# 8     14.7  169.27  16.65  15.6
# 9     21.2  396.90  34.41  14.4

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

X_train_prep = scaler.fit_transform(X_train)
X_val_prep = scaler.transform(X_val)
X_test_prep = scaler.transform(X_test)

# %%
regre = LinearRegression()
regre.fit(X_train_prep, y_train)
pred = regre.predict(X_test_prep)

# %%
x = range(0, len(y_test))
plt.scatter(x, y_test, color='red', label='datos')
plt.plot(x, pred, color='blue', label='predicción')
plt.legend()
plt.show()

# %% [markdown]
# ### KERAS

# %%
from keras import models, layers

network = models.Sequential()

network.add(layers.Dense(30, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(10, activation='relu'))
network.add(layers.Dense(1)) # No hay activation ya que es regresion

network.compile(loss='mean_squared_error',
                optimizer='sgd',
                metrics=['accuracy', 'Precision'])

# %%
history = network.fit(X_train_prep,
                      y_train,
                      epochs=50,
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 28ms/step - loss: 429.2762 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 67.5153 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 2/50
# 13/13 [==============================] - 0s 5ms/step - loss: 201.8317 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 42.5216 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 3/50
# 13/13 [==============================] - 0s 5ms/step - loss: 33.0953 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 106.9708 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 4/50
# 13/13 [==============================] - 0s 5ms/step - loss: 66.3079 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 19.2020 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 5/50
# 13/13 [==============================] - 0s 5ms/step - loss: 50.8675 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 31.1778 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 6/50
# 13/13 [==============================] - 0s 5ms/step - loss: 31.5801 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 32.9396 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 7/50
# 13/13 [==============================] - 0s 5ms/step - loss: 28.2092 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 27.5684 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 8/50
# 13/13 [==============================] - 0s 5ms/step - loss: 18.1630 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 31.1981 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 9/50
# 13/13 [==============================] - 0s 5ms/step - loss: 38.9254 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 67.4834 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 10/50
# 13/13 [==============================] - 0s 5ms/step - loss: 45.0609 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 35.1554 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 11/50
# 13/13 [==============================] - 0s 5ms/step - loss: 24.6969 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 36.0284 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 12/50
# 13/13 [==============================] - 0s 5ms/step - loss: 33.5462 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 36.4805 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 13/50
# 13/13 [==============================] - 0s 5ms/step - loss: 21.8408 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 33.7421 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 14/50
# 13/13 [==============================] - 0s 5ms/step - loss: 23.7106 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 49.8640 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 15/50
# 13/13 [==============================] - 0s 5ms/step - loss: 28.6099 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 37.1938 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 16/50
# 13/13 [==============================] - 0s 5ms/step - loss: 16.7423 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 36.8432 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 17/50
# 13/13 [==============================] - 0s 4ms/step - loss: 20.8892 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 40.9436 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 18/50
# 13/13 [==============================] - 0s 4ms/step - loss: 22.6726 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 63.1742 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 19/50
# 13/13 [==============================] - 0s 5ms/step - loss: 14.6112 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 42.0096 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 20/50
# 13/13 [==============================] - 0s 4ms/step - loss: 19.1642 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 45.1475 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 21/50
# 13/13 [==============================] - 0s 4ms/step - loss: 39.4315 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 41.9005 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 22/50
# 13/13 [==============================] - 0s 4ms/step - loss: 22.3350 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 42.9450 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 23/50
# 13/13 [==============================] - 0s 4ms/step - loss: 19.2036 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 59.7498 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 24/50
# 13/13 [==============================] - 0s 5ms/step - loss: 21.5246 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 46.2569 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 25/50
# 13/13 [==============================] - 0s 5ms/step - loss: 23.0344 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 43.8879 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 26/50
# 13/13 [==============================] - 0s 4ms/step - loss: 17.0535 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 59.4783 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 27/50
# 13/13 [==============================] - 0s 4ms/step - loss: 19.2764 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 57.0073 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 28/50
# 13/13 [==============================] - 0s 4ms/step - loss: 21.0902 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 37.1483 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 29/50
# 13/13 [==============================] - 0s 4ms/step - loss: 15.6959 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 37.8388 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 30/50
# 13/13 [==============================] - 0s 4ms/step - loss: 15.0143 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 52.8999 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 31/50
# 13/13 [==============================] - 0s 4ms/step - loss: 17.2248 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 46.3626 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 32/50
# 13/13 [==============================] - 0s 5ms/step - loss: 15.6729 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 42.3928 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 33/50
# 13/13 [==============================] - 0s 5ms/step - loss: 19.3457 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 39.7916 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 34/50
# 13/13 [==============================] - 0s 5ms/step - loss: 17.4762 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 43.2363 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 35/50
# 13/13 [==============================] - 0s 4ms/step - loss: 12.3423 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 38.6805 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 36/50
# 13/13 [==============================] - 0s 5ms/step - loss: 13.9024 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 38.3503 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 37/50
# 13/13 [==============================] - 0s 5ms/step - loss: 12.4112 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 36.3048 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 38/50
# 13/13 [==============================] - 0s 5ms/step - loss: 12.8929 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 55.4023 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 39/50
# 13/13 [==============================] - 0s 4ms/step - loss: 32.3646 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 45.5767 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 40/50
# 13/13 [==============================] - 0s 5ms/step - loss: 18.0231 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 44.1384 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 41/50
# 13/13 [==============================] - 0s 5ms/step - loss: 15.6901 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 45.6402 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 42/50
# 13/13 [==============================] - 0s 5ms/step - loss: 12.5121 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 44.5706 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 43/50
# 13/13 [==============================] - 0s 4ms/step - loss: 14.0585 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 35.8295 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 44/50
# 13/13 [==============================] - 0s 5ms/step - loss: 12.0833 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 37.1811 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 45/50
# 13/13 [==============================] - 0s 4ms/step - loss: 13.1712 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 29.4077 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 46/50
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8580 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 33.7402 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 47/50
# 13/13 [==============================] - 0s 5ms/step - loss: 10.7280 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 38.3221 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 48/50
# 13/13 [==============================] - 0s 5ms/step - loss: 21.0717 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 35.8137 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 49/50
# 13/13 [==============================] - 0s 5ms/step - loss: 11.5538 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 38.2500 - val_accuracy: 0.0000e+00 - val_precision: 1.0000
# Epoch 50/50
# 13/13 [==============================] - 0s 5ms/step - loss: 10.4840 - accuracy: 0.0000e+00 - precision: 1.0000 - val_loss: 33.2924 - val_accuracy: 0.0000e+00 - val_precision: 1.0000

# %%
df2 = pd.DataFrame(X_test_prep, columns=features[:-1])
df2.head(2)
# Out:
#        CRIM   ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  0.386189  0.0  0.762529   0.0  1.870787 -0.104188  0.386632 -0.501266
# 1  0.098704  0.0 -0.269082   1.0 -0.174157  0.926796 -0.016452  0.042685
#
#     RAD       TAX   PTRATIO         B     LSTAT
# 0  0.00  0.188630 -1.478992 -0.858739  0.265131
# 1  0.15 -0.059432 -0.571429 -0.040028 -0.143592

# %%
pred_keras = network.predict(df2)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
x = range(0, len(y_test))
plt.scatter(x, y_test, color='red', label='datos')
plt.plot(x, pred_keras, color='blue', label='predicción')
plt.legend()
plt.show()

# %%
x = range(0, len(y_test))
plt.scatter(x, pred, color='orange', label='sklearn')
plt.plot(x, pred_keras, color='green', label='keras')
plt.legend()
plt.show()

# %%
x = range(0, len(y_test))
plt.scatter(x, y_test, color='red', label='datos')
plt.plot(x, pred, color='orange', label='sklearn')
plt.plot(x, pred_keras, color='green', label='keras')
plt.legend()
plt.show()

# %%
r2_keras = metrics.r2_score(y_test, pred_keras.flatten())
r2_sk = metrics.r2_score(y_test, pred)

print(f'r2 keras: {r2_keras}')
print(f'r2 sklearn: {r2_sk}')
# Out:
# r2 keras: 0.8552244625263404
# r2 sklearn: 0.7992665395565144
